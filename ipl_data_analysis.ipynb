# %%
import pandas as pd
df=pd.read_csv("ipl_ball_by_ball_data.csv")

# %%
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
df.shape
# Out:
# (150460, 21)

# %%
len(df['match_id'].unique())
# Out:
# 636

# %%
match_ids = df['match_id'].unique()
print(match_ids[:5])
# Out:
# [1 2 3 4 5]

# %%
match_df = df[df['match_id'] == 2]

# %%
match_df
# Out:
#      match_id  inning            batting_team            bowling_team  over  \
# 248         2       1          Mumbai Indians  Rising Pune Supergiant     1
# 249         2       1          Mumbai Indians  Rising Pune Supergiant     1
# 250         2       1          Mumbai Indians  Rising Pune Supergiant     1
# 251         2       1          Mumbai Indians  Rising Pune Supergiant     1
# 252         2       1          Mumbai Indians  Rising Pune Supergiant     1
# ..        ...     ...                     ...                     ...   ...
# 490         2       2  Rising Pune Supergiant          Mumbai Indians    20
# 491         2       2  Rising Pune Supergiant          Mumbai Indians    20
# 492         2       2  Rising Pune Supergiant          Mumbai Indians    20
# 493         2       2  Rising Pune Supergiant          Mumbai Indians    20
# 494         2       2  Rising Pune Supergiant          Mumbai Indians    20
#
# ...

# %%
match_df = match_df.sort_values(by=['inning', 'over', 'ball'])

# %%
match_df
# Out:
#      match_id  inning            batting_team            bowling_team  over  \
# 248         2       1          Mumbai Indians  Rising Pune Supergiant     1
# 249         2       1          Mumbai Indians  Rising Pune Supergiant     1
# 250         2       1          Mumbai Indians  Rising Pune Supergiant     1
# 251         2       1          Mumbai Indians  Rising Pune Supergiant     1
# 252         2       1          Mumbai Indians  Rising Pune Supergiant     1
# ..        ...     ...                     ...                     ...   ...
# 490         2       2  Rising Pune Supergiant          Mumbai Indians    20
# 491         2       2  Rising Pune Supergiant          Mumbai Indians    20
# 492         2       2  Rising Pune Supergiant          Mumbai Indians    20
# 493         2       2  Rising Pune Supergiant          Mumbai Indians    20
# 494         2       2  Rising Pune Supergiant          Mumbai Indians    20
#
# ...

# %%
match_df = match_df.reset_index(drop=True)

# %%
match_df
# Out:
#      match_id  inning            batting_team            bowling_team  over  \
# 0           2       1          Mumbai Indians  Rising Pune Supergiant     1
# 1           2       1          Mumbai Indians  Rising Pune Supergiant     1
# 2           2       1          Mumbai Indians  Rising Pune Supergiant     1
# 3           2       1          Mumbai Indians  Rising Pune Supergiant     1
# 4           2       1          Mumbai Indians  Rising Pune Supergiant     1
# ..        ...     ...                     ...                     ...   ...
# 242         2       2  Rising Pune Supergiant          Mumbai Indians    20
# 243         2       2  Rising Pune Supergiant          Mumbai Indians    20
# 244         2       2  Rising Pune Supergiant          Mumbai Indians    20
# 245         2       2  Rising Pune Supergiant          Mumbai Indians    20
# 246         2       2  Rising Pune Supergiant          Mumbai Indians    20
#
# ...

# %%
match_df['is_wicket'] = match_df['player_dismissed'].notna().astype(int)

# %%
match_df.head()
# Out:
#    match_id  inning    batting_team            bowling_team  over  ball  \
# 0         2       1  Mumbai Indians  Rising Pune Supergiant     1     1
# 1         2       1  Mumbai Indians  Rising Pune Supergiant     1     2
# 2         2       1  Mumbai Indians  Rising Pune Supergiant     1     3
# 3         2       1  Mumbai Indians  Rising Pune Supergiant     1     4
# 4         2       1  Mumbai Indians  Rising Pune Supergiant     1     5
#
#       batsman non_striker    bowler  is_super_over  ...  legbye_runs  \
# 0    PA Patel  JC Buttler  AB Dinda              0  ...            0
# 1    PA Patel  JC Buttler  AB Dinda              0  ...            0
# 2    PA Patel  JC Buttler  AB Dinda              0  ...            0
# 3  JC Buttler    PA Patel  AB Dinda              0  ...            0
# 4    PA Patel  JC Buttler  AB Dinda              0  ...            0
#
#    noball_runs  penalty_runs  batsman_runs  extra_runs  total_runs  \
# ...

# %%
match_df[['inning','over','ball','total_runs','is_wicket']].head(20)
# Out:
#     inning  over  ball  total_runs  is_wicket
# 0        1     1     1           1          0
# 1        1     1     2           0          0
# 2        1     1     3           1          0
# 3        1     1     4           5          0
# 4        1     1     5           4          0
# 5        1     1     6           0          0
# 6        1     1     7           0          0
# 7        1     2     1           4          0
# 8        1     2     2           0          0
# 9        1     2     3           4          0
# 10       1     2     4           0          0
# 11       1     2     5           0          0
# 12       1     2     6           0          0
# 13       1     3     1           0          0
# 14       1     3     2           4          0
# 15       1     3     3           0          0
# 16       1     3     4           0          0
# 17       1     3     5           4          0
# 18       1     3     6           1          0
# ...

# %%
# !pip install mysql-connector-python

# %%
import mysql.connector

conn = mysql.connector.connect(host="localhost",user="root",password="shiyam@123",  
    database="ipl_db")

print("Connected successfully")
# Out:
# Connected successfully

# %%
cursor = conn.cursor()

# %%
import time

query = """INSERT INTO ipl_live 
(match_id, inning, over_num, ball_num, batsman, bowler, total_runs, is_wicket)
VALUES (%s, %s, %s, %s, %s, %s, %s, %s)"""

for _, row in match_df.iterrows():
    values = (row['match_id'],row['inning'],row['over'],row['ball'],row['batsman'],
    row['bowler'],row['total_runs'],row['is_wicket'])

cursor.execute(query, values)
conn.commit()

print(f"Inserted: Over {row['over']}.{row['ball']} | Runs: {row['total_runs']}")
time.sleep(1)
# Out:
# Inserted: Over 20.5 | Runs: 6
